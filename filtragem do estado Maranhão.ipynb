# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\Maranhão.xlsx", sheet_name="Área colhida (Hectares)")
display(df)
# Out:
#                         Município Abacate Abacaxi* Açaí  \
# 0                 Açailândia (MA)       -        4    -
# 1               Afonso Cunha (MA)       -        -    -
# 2      Água Doce do Maranhão (MA)       -        -    -
# 3                  Alcântara (MA)       -        -    -
# 4              Aldeias Altas (MA)       -        -    -
# ..                            ...     ...      ...  ...
# 212                    Viana (MA)       -        -   40
# 213  Vila Nova dos Martírios (MA)       -        -    5
# 214        Vitória do Mearim (MA)       -        -    -
# 215          Vitorino Freire (MA)       -        -    -
# 216                  Zé Doca (MA)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                            -    -
# 2                             -                            -    -
# ...

# %%
new_df = []
for culture in df.columns[1:]:
    for index, row in df.iterrows():
        value = row[culture]
        if value != '-':
            new_df.append({
                'Cidade': row['Município'],
                'Área colhida (Hectares)': value,  
                'Nome': culture
            })
newdf = pd.DataFrame(new_df)
display(newdf)
# Out:
#                              Cidade  Área colhida (Hectares)      Nome
# 0                   Açailândia (MA)                        4  Abacaxi*
# 1               Cândido Mendes (MA)                       12  Abacaxi*
# 2                      Colinas (MA)                        7  Abacaxi*
# 3                    Dom Pedro (MA)                        3  Abacaxi*
# 4                     Estreito (MA)                        2  Abacaxi*
# ...                             ...                      ...       ...
# 1619  São Domingos do Maranhão (MA)                        2    Tomate
# 1620       São João do Paraíso (MA)                        7    Tomate
# 1621         Senador La Rocque (MA)                        3    Tomate
# 1622                Sítio Novo (MA)                       49    Tomate
# 1623                    Tuntum (MA)                        3    Tomate
#
# [1624 rows x 3 columns]

# %%
df2 = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\Maranhão.xlsx", sheet_name="Quantidade produzida (Tonela...")
display(df2)
# Out:
#                         Município Abacate Abacaxi* Açaí  \
# 0                 Açailândia (MA)       -       56    -
# 1               Afonso Cunha (MA)       -        -    -
# 2      Água Doce do Maranhão (MA)       -        -    -
# 3                  Alcântara (MA)       -        -    -
# 4              Aldeias Altas (MA)       -        -    -
# ..                            ...     ...      ...  ...
# 212                    Viana (MA)       -        -  216
# 213  Vila Nova dos Martírios (MA)       -        -   21
# 214        Vitória do Mearim (MA)       -        -    -
# 215          Vitorino Freire (MA)       -        -    -
# 216                  Zé Doca (MA)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                            -    -
# 2                             -                            -    -
# ...

# %%
new_df2 = []
for culture in df2.columns[1:]:
    for index, row in df2.iterrows():
        value = row[culture]
        if value != '-':
            new_df2.append({
                'Cidade': row['Município'],
                'Produção (toneladas)': value,  
                'Nome': culture
            })
newdf2 = pd.DataFrame(new_df2)
display(newdf2)
newdf["Produção (toneladas)"] = newdf2['Produção (toneladas)']
# Out:
#                              Cidade  Produção (toneladas)      Nome
# 0                   Açailândia (MA)                    56  Abacaxi*
# 1               Cândido Mendes (MA)                   139  Abacaxi*
# 2                      Colinas (MA)                   152  Abacaxi*
# 3                    Dom Pedro (MA)                    68  Abacaxi*
# 4                     Estreito (MA)                    22  Abacaxi*
# ...                             ...                   ...       ...
# 1619  São Domingos do Maranhão (MA)                    49    Tomate
# 1620       São João do Paraíso (MA)                   135    Tomate
# 1621         Senador La Rocque (MA)                    56    Tomate
# 1622                Sítio Novo (MA)                  1045    Tomate
# 1623                    Tuntum (MA)                    48    Tomate
#
# [1624 rows x 3 columns]

# %%
newdf.to_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\resultados\\resultados MARANHÃO.xlsx", sheet_name="Planilha 1", index=False)
