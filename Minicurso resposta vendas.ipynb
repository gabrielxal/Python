# %% [markdown]
# ## Introdução ao Google Colab

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #  Leitura do página Vendas

# %%
df_vendas = pd.read_excel("/content/drive/MyDrive/Minicurso/Minicurso códigos de introdução.xlsx", sheet_name="Vendas")

# %% [markdown]
# # Visualização de dados

# %%
df_vendas.head(3)
# Out:
#    ID_Venda qual produto  quantia  preço u       Data
# 0         1    Produto A        6    72.93 2024-01-01
# 1         2    Produto B       17    20.60 2024-01-02
# 2         3    Produto C       17    82.85 2024-01-03

# %%
df_vendas.shape
# Out:
# (10, 5)

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Venda      10 non-null     int64
#  1   qual produto  8 non-null      object
#  2   quantia       10 non-null     int64
#  3   preço u       10 non-null     float64
#  4   Data          10 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 528.0+ bytes

# %%
df_vendas
# Out:
#    ID_Venda qual produto  quantia  preço u       Data
# 0         1    Produto A        6    72.93 2024-01-01
# 1         2    Produto B       17    20.60 2024-01-02
# 2         3    Produto C       17    82.85 2024-01-03
# 3         4    Produto D        7    91.29 2024-01-04
# 4         5    Produto E       19    61.40 2024-01-05
# 5         6          NaN        3    48.46 2024-01-06
# 6         7          NaN        2    74.09 2024-01-07
# 7         8    Produto H        7    74.53 2024-01-08
# 8         9    Produto I       14    47.07 2024-01-09
# 9        10    Produto J        4    19.49 2024-01-10

# %%
df_vendas['Data'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Manipulação de Dados

# %%
df_vendas = df_vendas.rename(columns={'qual produto':'Produtos', 'quantia':'Quantidade', "preço u": "Preço Unitário"})

# %%
df_filtrado = df_vendas[["Produtos", "Preço Unitário"]]
df_filtrado
# Out:
#     Produtos  Preço Unitário
# 0  Produto A           72.93
# 1  Produto B           20.60
# 2  Produto C           82.85
# 3  Produto D           91.29
# 4  Produto E           61.40
# 5        NaN           48.46
# 6        NaN           74.09
# 7  Produto H           74.53
# 8  Produto I           47.07
# 9  Produto J           19.49

# %% [markdown]
# ## Limpeza de dados

# %%
df_filtrado.dropna()
# Out:
#     Produtos  Preço Unitário
# 0  Produto A           72.93
# 1  Produto B           20.60
# 2  Produto C           82.85
# 3  Produto D           91.29
# 4  Produto E           61.40
# 7  Produto H           74.53
# 8  Produto I           47.07
# 9  Produto J           19.49

# %%
df_filtrado["Produtos"] = df_filtrado["Produtos"].fillna("Produto sem especificação")
# Out:
# <ipython-input-77-433ea2ae14a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado["Produtos"] = df_filtrado["Produtos"].fillna("Produto sem especificação")

# %%
df_filtrado
# Out:
#                     Produtos  Preço Unitário
# 0                  Produto A           72.93
# 1                  Produto B           20.60
# 2                  Produto C           82.85
# 3                  Produto D           91.29
# 4                  Produto E           61.40
# 5  Produto sem especificação           48.46
# 6  Produto sem especificação           74.09
# 7                  Produto H           74.53
# 8                  Produto I           47.07
# 9                  Produto J           19.49

# %% [markdown]
# # Transformação de dados

# %%
pd.to_datetime(df_vendas['Data'], format='%Y/%m/%d')
# Out:
# 0   2024-01-01
# 1   2024-01-02
# 2   2024-01-03
# 3   2024-01-04
# 4   2024-01-05
# 5   2024-01-06
# 6   2024-01-07
# 7   2024-01-08
# 8   2024-01-09
# 9   2024-01-10
# Name: Data, dtype: datetime64[ns]

# %%
def somar_coluna(coluna):
    return df_filtrado[coluna].sum()

valor_total = somar_coluna('Preço Unitário')
valor_total
# Out:
# 592.71

# %% [markdown]
# # Estatística

# %%
df_filtrado['Preço Unitário'].mean()
# Out:
# 59.271

# %%
df_filtrado.describe
# Out:
# <bound method NDFrame.describe of                     Produtos  Preço Unitário
# 0                  Produto A           72.93
# 1                  Produto B           20.60
# 2                  Produto C           82.85
# 3                  Produto D           91.29
# 4                  Produto E           61.40
# 5  Produto sem especificação           48.46
# 6  Produto sem especificação           74.09
# 7                  Produto H           74.53
# 8                  Produto I           47.07
# 9                  Produto J           19.49>

# %%
df_filtrado['Produtos'].value_counts()
# Out:
# Produtos
# Produto sem especificação    2
# Produto A                    1
# Produto B                    1
# Produto C                    1
# Produto D                    1
# Produto E                    1
# Produto H                    1
# Produto I                    1
# Produto J                    1
# Name: count, dtype: int64

# %%
df_filtrado['Produtos']
