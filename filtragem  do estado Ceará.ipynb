# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\CEARÁ.xlsx", sheet_name="Área colhida (Hectares)")
display(df)
# Out:
#                 Município Abacate Abacaxi* Açaí Algodão arbóreo (em caroço)  \
# 0            Abaiara (CE)       -        -    -                           -
# 1            Acarape (CE)       -        -    -                           -
# 2             Acaraú (CE)       -        -    -                           -
# 3           Acopiara (CE)       -        -    -                           -
# 4             Aiuaba (CE)       -        -    -                           -
# ..                    ...     ...      ...  ...                         ...
# 179      Uruburetama (CE)       9        -    -                           -
# 180           Uruoca (CE)       -        -    -                           -
# 181          Varjota (CE)       -        -    -                           -
# 182    Várzea Alegre (CE)       -        -    -                           -
# 183  Viçosa do Ceará (CE)     110        -    -                           -
#
# ...

# %%
new_df = []
for culture in df.columns[1:]:
    for index, row in df.iterrows():
        value = row[culture]
        if value != '-':
            new_df.append({
                'Cidade': row['Município'],
                'Área colhida (Hectares)': value,  
                'Nome': culture
            })
newdf = pd.DataFrame(new_df)
display(newdf)
# Out:
#                 Cidade  Área colhida (Hectares)     Nome
# 0        Baturité (CE)                        1  Abacate
# 1     Brejo Santo (CE)                        2  Abacate
# 2       Carnaubal (CE)                       20  Abacate
# 3           Crato (CE)                        2  Abacate
# 4          Croatá (CE)                       10  Abacate
# ...                ...                      ...      ...
# 2229     Barbalha (CE)                       11      Uva
# 2230        Barro (CE)                        2      Uva
# 2231   Jaguaruana (CE)                        6      Uva
# 2232      Mauriti (CE)                        2      Uva
# 2233       Russas (CE)                        2      Uva
#
# [2234 rows x 3 columns]

# %%
df2 = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\CEARÁ.xlsx", sheet_name="Quantidade produzida (Tonela...")
display(df2)
# Out:
#                 Município Abacate Abacaxi* Açaí Algodão arbóreo (em caroço)  \
# 0            Abaiara (CE)       -        -    -                           -
# 1            Acarape (CE)       -        -    -                           -
# 2             Acaraú (CE)       -        -    -                           -
# 3           Acopiara (CE)       -        -    -                           -
# 4             Aiuaba (CE)       -        -    -                           -
# ..                    ...     ...      ...  ...                         ...
# 179      Uruburetama (CE)     108        -    -                           -
# 180           Uruoca (CE)       -        -    -                           -
# 181          Varjota (CE)       -        -    -                           -
# 182    Várzea Alegre (CE)       -        -    -                           -
# 183  Viçosa do Ceará (CE)    2058        -    -                           -
#
# ...

# %%
new_df2 = []
for culture in df2.columns[1:]:
    for index, row in df2.iterrows():
        value = row[culture]
        if value != '-':
            new_df2.append({
                'Cidade': row['Município'],
                'Produção (toneladas)': value,  
                'Nome': culture
            })
newdf2 = pd.DataFrame(new_df2)
display(newdf2)
newdf["Produção (toneladas)"] = newdf2['Produção (toneladas)']
# Out:
#                 Cidade  Produção (toneladas)     Nome
# 0        Baturité (CE)                     7  Abacate
# 1     Brejo Santo (CE)                    23  Abacate
# 2       Carnaubal (CE)                   200  Abacate
# 3           Crato (CE)                    20  Abacate
# 4          Croatá (CE)                    93  Abacate
# ...                ...                   ...      ...
# 2229     Barbalha (CE)                   334      Uva
# 2230        Barro (CE)                    43      Uva
# 2231   Jaguaruana (CE)                   103      Uva
# 2232      Mauriti (CE)                    63      Uva
# 2233       Russas (CE)                    40      Uva
#
# [2234 rows x 3 columns]

# %%
newdf.to_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\Reresultados CEARÁ.xlsx", sheet_name="Planilha 1", index=False)
