# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\PIAUÍ.xlsx", sheet_name="Área colhida (Hectares)")
display(df)
# Out:
#                    Município Abacate Abacaxi* Açaí  \
# 0                 Acauã (PI)       -        -    -
# 1          Agricolândia (PI)       -        -    -
# 2           Água Branca (PI)       -        -    -
# 3    Alagoinha do Piauí (PI)       -        -    -
# 4     Alegrete do Piauí (PI)       -        -    -
# ..                       ...     ...      ...  ...
# 219       Várzea Branca (PI)       -        -    -
# 220       Várzea Grande (PI)       -        -    -
# 221         Vera Mendes (PI)       -        -    -
# 222  Vila Nova do Piauí (PI)       -        -    -
# 223         Wall Ferraz (PI)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                            -    -
# 2                             -                            -    -
# 3                             -                            -    -
# ...

# %%
new_df = []
for culture in df.columns[1:]:
    for index, row in df.iterrows():
        value = row[culture]
        if value != '-':
            new_df.append({
                'Cidade': row['Município'],
                'Área colhida (Hectares)': value,  
                'Nome': culture
            })
newdf = pd.DataFrame(new_df)
display(newdf)
# Out:
#                               Cidade  Área colhida (Hectares)  \
# 0             Alegrete do Piauí (PI)                       15
# 1       Baixa Grande do Ribeiro (PI)                      300
# 2            Barreiras do Piauí (PI)                      640
# 3              Betânia do Piauí (PI)                       30
# 4     Caldeirão Grande do Piauí (PI)                       12
# ...                              ...                      ...
# 1460          Jacobina do Piauí (PI)                        2
# 1461                      Picos (PI)                       10
# 1462         São Pedro do Piauí (PI)                        2
# 1463                     Simões (PI)                       20
# 1464          São João do Piauí (PI)                        2
#
#                               Nome
# 0     Algodão herbáceo (em caroço)
# 1     Algodão herbáceo (em caroço)
# 2     Algodão herbáceo (em caroço)
# 3     Algodão herbáceo (em caroço)
# 4     Algodão herbáceo (em caroço)
# ...

# %%
df2 = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\PIAUÍ.xlsx", sheet_name="Quantidade produzida (Tonela...")
display(df2)
# Out:
#                    Município Abacate Abacaxi* Açaí  \
# 0                 Acauã (PI)       -        -    -
# 1          Agricolândia (PI)       -        -    -
# 2           Água Branca (PI)       -        -    -
# 3    Alagoinha do Piauí (PI)       -        -    -
# 4     Alegrete do Piauí (PI)       -        -    -
# ..                       ...     ...      ...  ...
# 219       Várzea Branca (PI)       -        -    -
# 220       Várzea Grande (PI)       -        -    -
# 221         Vera Mendes (PI)       -        -    -
# 222  Vila Nova do Piauí (PI)       -        -    -
# 223         Wall Ferraz (PI)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                            -    -
# 2                             -                            -    -
# 3                             -                            -    -
# ...

# %%
new_df2 = []
for culture in df2.columns[1:]:
    for index, row in df2.iterrows():
        value = row[culture]
        if value != '-':
            new_df2.append({
                'Cidade': row['Município'],
                'Produção (toneladas)': value,  
                'Nome': culture
            })
newdf2 = pd.DataFrame(new_df2)
display(newdf2)
newdf["Produção (toneladas)"] = newdf2['Produção (toneladas)']
# Out:
#                               Cidade  Produção (toneladas)  \
# 0             Alegrete do Piauí (PI)                     9
# 1       Baixa Grande do Ribeiro (PI)                  1125
# 2            Barreiras do Piauí (PI)                  2688
# 3              Betânia do Piauí (PI)                     7
# 4     Caldeirão Grande do Piauí (PI)                     8
# ...                              ...                   ...
# 1460          Jacobina do Piauí (PI)                    36
# 1461                      Picos (PI)                   200
# 1462         São Pedro do Piauí (PI)                    30
# 1463                     Simões (PI)                   600
# 1464          São João do Piauí (PI)                    24
#
#                               Nome
# 0     Algodão herbáceo (em caroço)
# 1     Algodão herbáceo (em caroço)
# 2     Algodão herbáceo (em caroço)
# 3     Algodão herbáceo (em caroço)
# 4     Algodão herbáceo (em caroço)
# ...                            ...
# ...

# %%
newdf.to_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\resultados 2022\\resultados PIAUÍ.xlsx", sheet_name="Planilha 1", index=False)
