# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\PERNAMBUCO.xlsx", sheet_name="Área colhida (Hectares)")
display(df)
# Out:
#                        Município Abacate Abacaxi* Açaí  \
# 0              Abreu e Lima (PE)       -       20    -
# 1     Afogados da Ingazeira (PE)       -        -    -
# 2                   Afrânio (PE)       -        -    -
# 3                 Agrestina (PE)       -        -    -
# 4                Água Preta (PE)       -       15    -
# ..                           ...     ...      ...  ...
# 180       Vertente do Lério (PE)       -        -    -
# 181               Vertentes (PE)       -        -    -
# 182                Vicência (PE)       5        -    -
# 183  Vitória de Santo Antão (PE)       -        -    -
# 184                   Xexéu (PE)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                           12    -
# 2                             -                            -    -
# ...

# %%
new_df = []
for culture in df.columns[1:]:
    for index, row in df.iterrows():
        value = row[culture]
        if value != '-':
            new_df.append({
                'Cidade': row['Município'],
                'Área colhida (Hectares)': value,  
                'Nome': culture
            })
newdf = pd.DataFrame(new_df)
display(newdf)
# Out:
#                              Cidade Área colhida (Hectares)     Nome
# 0                      Aliança (PE)                       4  Abacate
# 1       Brejo da Madre de Deus (PE)                       2  Abacate
# 2                    Camutanga (PE)                      10  Abacate
# 3                      Caruaru (PE)                       4  Abacate
# 4          Fernando de Noronha (PE)                     ...  Abacate
# ...                             ...                     ...      ...
# 1639                 Petrolina (PE)                    5500      Uva
# 1640                    Recife (PE)                     ...      Uva
# 1641  Santa Maria da Boa Vista (PE)                     280      Uva
# 1642        São Vicente Férrer (PE)                     600      Uva
# 1643                  Toritama (PE)                     ...      Uva
#
# [1644 rows x 3 columns]

# %%
df2 = pd.read_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\PERNAMBUCO.xlsx", sheet_name="Quantidade produzida (Tonela...")
display(df2)
# Out:
#                        Município Abacate Abacaxi* Açaí  \
# 0              Abreu e Lima (PE)       -      633    -
# 1     Afogados da Ingazeira (PE)       -        -    -
# 2                   Afrânio (PE)       -        -    -
# 3                 Agrestina (PE)       -        -    -
# 4                Água Preta (PE)       -      160    -
# ..                           ...     ...      ...  ...
# 180       Vertente do Lério (PE)       -        -    -
# 181               Vertentes (PE)       -        -    -
# 182                Vicência (PE)      25        -    -
# 183  Vitória de Santo Antão (PE)       -        -    -
# 184                   Xexéu (PE)       -        -    -
#
#     Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                             -                            -    -
# 1                             -                           12    -
# 2                             -                            -    -
# ...

# %%
new_df2 = []
for culture in df2.columns[1:]:
    for index, row in df2.iterrows():
        value = row[culture]
        if value != '-':
            new_df2.append({
                'Cidade': row['Município'],
                'Produção (toneladas)': value,  
                'Nome': culture
            })
newdf2 = pd.DataFrame(new_df2)
display(newdf2)
newdf["Produção (toneladas)"] = newdf2['Produção (toneladas)']
# Out:
#                              Cidade Produção (toneladas)     Nome
# 0                      Aliança (PE)                   13  Abacate
# 1       Brejo da Madre de Deus (PE)                   10  Abacate
# 2                    Camutanga (PE)                   60  Abacate
# 3                      Caruaru (PE)                   16  Abacate
# 4          Fernando de Noronha (PE)                  ...  Abacate
# ...                             ...                  ...      ...
# 1639                 Petrolina (PE)               236500      Uva
# 1640                    Recife (PE)                  ...      Uva
# 1641  Santa Maria da Boa Vista (PE)                11760      Uva
# 1642        São Vicente Férrer (PE)                16200      Uva
# 1643                  Toritama (PE)                  ...      Uva
#
# [1644 rows x 3 columns]

# %%
newdf.to_excel("C:\\Users\\Aluno\\Documents\\Gabriel\\PRH 55.1\\Mapeamento - Banco de dados\\resultados 2022\\resultados PERNAMBUCO.xlsx", sheet_name="Planilha 1", index=False)
